# %%
import pandas as pd
df1=pd.read_csv("C:/Users/saifu/Webpage(URL)/real.csv")
dm=df1.append(df3,ignore_index=True)
dm.to_csv("C:/Users/saifu/Webpage(URL)/test.csv")
dt.to_csv("C:/Users/saifu/Webpage(URL)/news.csv",index=False)
tf={"id":['6336'],"title":['Sputnik V Approved By Experts, Third Vaccine For India'],"text":[' New Delhi: Russia Covid vaccine Sputnik V has been recommended for use in India by a committee of experts as the country battles a record spike in infections. If approved, this will be the third vaccine to be used in India after Serum Institute of India Covishield - developed by Oxford-AstraZeneca - and Bharat Biotech Covaxin.Sputnik V, manufactured in India by Dr Reddy s, has the highest effectiveness - 91.6 per cent -- after the Moderna and Pfizer shots. Dr Reddy s had applied on February 19 for emergency use of the vaccine, which is in Phase 3 of clinical trials in India.After the recommendation of the Subject Expert Committee (SEC) of the Central Drugs Standard Control Organization, the vaccine has to be greenlit by the Drug Controller General of India before it can be widely used to inoculate citizens. Sputnik V has made it to the top of the queue amid complaints of vaccine shortage from many states, especially Maharashtra, the epicenter of the second surge of Covid.'],"label":['REAL']}
df1.drop('Unnamed: 0',axis=1,inplace=True)

# %%
import pandas as pd
df1=pd.read_csv("C:/Users/saifu/Webpage(URL)/news.csv")
df1.drop('Unnamed: 0',axis=1,inplace=True)
df1
# Out:
#                                                   title  \
# 0                          You Can Smell Hillary’s Fear
# 1     Watch The Exact Moment Paul Ryan Committed Pol...
# 2           Kerry to go to Paris in gesture of sympathy
# 3     Bernie supporters on Twitter erupt in anger ag...
# 4      The Battle of New York: Why This Primary Matters
# ...                                                 ...
# 6330  State Department says it can't find emails fro...
# 6331  The ‘P’ in PBS Should Stand for ‘Plutocratic’ ...
# 6332  Anti-Trump Protesters Are Tools of the Oligarc...
# 6333  In Ethiopia, Obama seeks progress on peace, se...
# 6334  Jeb Bush Is Suddenly Attacking Trump. Here's W...
#
#                                                    text label
# 0     Daniel Greenfield, a Shillman Journalism Fello...  FAKE
# 1     Google Pinterest Digg Linkedin Reddit Stumbleu...  FAKE
# 2     U.S. Secretary of State John F. Kerry said Mon...  REAL
# ...

# %%
import pandas as pd
df1=pd.read_csv("C:/Users/saifu/Webpage(URL)/news.csv")
df1.drop('Unnamed: 0',axis=1,inplace=True)
tf={"title":'Xavi Hernandez leads Al-Sadd into Asian Champions League',"text":'Xavi Hernandez leads Al-Sadd into Asian Champions League.SEOUL: Xavi Hernandez was touted as a future.',"label":'REAL'}
dm=df1.append(tf,ignore_index=True)
dm.to_csv("C:/Users/saifu/Webpage(URL)/news.csv")

# %%
dm
# Out:
#                                                   title  \
# 0                          You Can Smell Hillary’s Fear
# 1     Watch The Exact Moment Paul Ryan Committed Pol...
# 2           Kerry to go to Paris in gesture of sympathy
# 3     Bernie supporters on Twitter erupt in anger ag...
# 4      The Battle of New York: Why This Primary Matters
# ...                                                 ...
# 6337  OPPO F19 with 33W Flash Charge – another sleek...
# 6338  IPL 2021: Shah Rukh Khan apologises to fans af...
# 6339  India Clears Way For Foreign-Made Vaccines, Wa...
# 6340  Stocks in news: TCS, YES Bank, Vedanta, Adani ...
# 6341  Xavi Hernandez leads Al-Sadd into Asian Champi...
#
#                                                    text label
# 0     Daniel Greenfield, a Shillman Journalism Fello...  FAKE
# 1     Google Pinterest Digg Linkedin Reddit Stumbleu...  FAKE
# 2     U.S. Secretary of State John F. Kerry said Mon...  REAL
# ...

# %%
dm
# Out:
#                                                   title  \
# 0                          You Can Smell Hillary’s Fear
# 1     Watch The Exact Moment Paul Ryan Committed Pol...
# 2           Kerry to go to Paris in gesture of sympathy
# 3     Bernie supporters on Twitter erupt in anger ag...
# 4      The Battle of New York: Why This Primary Matters
# ...                                                 ...
# 6337  Sputnik V Approved By Experts, Third Vaccine F...
# 6338  Airtel, Jio, Vi best prepaid plans with stream...
# 6339  As Delhi Touches Yet Another Peak of Over 11k ...
# 6340  Unemployment rate rises as Covid-19 returns to...
# 6341  India gets third Covid-19 vaccine, how it may ...
#
#                                                    text label
# 0     Daniel Greenfield, a Shillman Journalism Fello...  FAKE
# 1     Google Pinterest Digg Linkedin Reddit Stumbleu...  FAKE
# 2     U.S. Secretary of State John F. Kerry said Mon...  REAL
# ...

# %%
df1.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df1
# Out:
#                                                   title  \
# 0                          You Can Smell Hillary’s Fear
# 1     Watch The Exact Moment Paul Ryan Committed Pol...
# 2           Kerry to go to Paris in gesture of sympathy
# 3     Bernie supporters on Twitter erupt in anger ag...
# 4      The Battle of New York: Why This Primary Matters
# ...                                                 ...
# 6335  Sputnik V Approved By Experts, Third Vaccine F...
# 6336  Sputnik V Approved By Experts, Third Vaccine F...
# 6337  Sputnik V Approved By Experts, Third Vaccine F...
# 6338  Airtel, Jio, Vi best prepaid plans with stream...
# 6339  As Delhi Touches Yet Another Peak of Over 11k ...
#
#                                                    text label
# 0     Daniel Greenfield, a Shillman Journalism Fello...  FAKE
# 1     Google Pinterest Digg Linkedin Reddit Stumbleu...  FAKE
# 2     U.S. Secretary of State John F. Kerry said Mon...  REAL
# ...

# %%
tf={"title":'Unemployment rate rises as Covid-19 returns to haunt Indian economy',"text":'Unemployment rate rises as Covid-19 returns to haunt Indian economy.Job losses have started hitting the gig economy with a sharp rise in Covid-19 cases during the second wave. A private research report suggests that the unemployment rate has started rising since April.Data released by the Centre for Monitoring Indian Economy, a Mumbai-based think tank, suggested that unemployment has again started rising in the country. The unemployment rate touched 8.6 per cent for the week ending April 11, from just 6.7 per cent two weeks ago, according to fresh data released by CMIE.With migrant labourers retreating to their native places, the impact seems to be more severe in urban areas where the unemployment rate is now reaching 10 per cent.Maharashtra, which has been reporting the highest number of cases in India, was the first to announce partial lockdown measures. State authorities said that a decision on a complete lockdown will be taken this week.Other states have also imposed restrictions like night curfews and may soon opt for stricter measures if average daily cases continue to rise rapidly.',"label":'REAL'}

# %%
dm=df1.append(tf,ignore_index=True)

# %%
dm
# Out:
#                                                   title  \
# 0                          You Can Smell Hillary’s Fear
# 1     Watch The Exact Moment Paul Ryan Committed Pol...
# 2           Kerry to go to Paris in gesture of sympathy
# 3     Bernie supporters on Twitter erupt in anger ag...
# 4      The Battle of New York: Why This Primary Matters
# ...                                                 ...
# 6336  Sputnik V Approved By Experts, Third Vaccine F...
# 6337  Sputnik V Approved By Experts, Third Vaccine F...
# 6338  Airtel, Jio, Vi best prepaid plans with stream...
# 6339  As Delhi Touches Yet Another Peak of Over 11k ...
# 6340  Unemployment rate rises as Covid-19 returns to...
#
#                                                    text label
# 0     Daniel Greenfield, a Shillman Journalism Fello...  FAKE
# 1     Google Pinterest Digg Linkedin Reddit Stumbleu...  FAKE
# 2     U.S. Secretary of State John F. Kerry said Mon...  REAL
# ...

# %%
dm.to_csv("C:/Users/saifu/Webpage(URL)/news.csv")
